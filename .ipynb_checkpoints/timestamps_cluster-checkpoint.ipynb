# %% [markdown]
# # Library import

# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
from sklearn.cluster import DBSCAN
import math
from scipy import stats
import matplotlib.pyplot as plt

# %%
raw_data=pd.read_csv("./data_SNat/CDSA_EssaimSaintes_2004-2005_lat-lon.txt",sep='\t')

# %% [markdown]
# ## Data preprocessing

# %%
datetime.fromisoformat('1900-01-01')+timedelta(seconds=3345210427.94)
# Out:
# datetime.datetime(2006, 1, 2, 17, 7, 7, 940000)

# %%
def transform_todatetime(data):
    data['sec']= data['sec'].apply(lambda x :datetime.fromisoformat('1900-01-01')+timedelta(seconds=x))
    return data

# %%
def loading_data(raw_data):
    df1=raw_data.copy()
    df1=transform_todatetime(df1)
    df1['date']=df1['sec'].dt.date
    return df1

# %% [markdown]
# ### Clustering with DBSCAN , high min_dist

# %%
df1=loading_data(raw_data)
def apply_dbscan(ep,samp,df):
    
    clusters = DBSCAN(eps = ep, min_samples=samp)
    clusters.fit(df[['lat', 'lon']])
    df['labels'] = [str(e) for e in clusters.labels_]
    return df



df1=apply_dbscan(0.02,20,df1)
import plotly.express as px



fig = px.scatter_mapbox(df1, lat="lat", lon="lon", color='labels')

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="f8908403-891d-4fed-ac82-3a2c305ebab9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8908403-891d-4fed-ac82-3a2c305ebab9")) {                    Plotly.newPlot(                        "f8908403-891d-4fed-ac82-3a2c305ebab9",                        [{"hovertemplate": "labels=0<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "lat": [15.838923999999999, 15.851628, 15.841689, 15.856257999999999, 15.854107999999998, 15.6795, 15.837333, 15.736051999999999, 15.836431, 15.781153, 15.834704, 15.725, 15.7345, 15.880507000000001, 15.787, 15.857085999999999, 15.855848000000002, 15.874535, 15.866082999999998, 15.862559, 15.87256, 15.870045000000001, 15.900376999999999, 15.871789999999999, 15.869803, 15.870048, 15.864839000000002, 15.878667000000002, 15.851616, 15.837679999999999, 15.861576999999999, 15.853373999999999, 15.869810000000001, 15.869566, 15.871795, 15.898667000000001, 15.855856, 15.895532999999999, 15.913332999999998, 15.878832999999998, 15.876782999999998, 15.871552, 15.873287, 15.88476, 15.863078, 15.897167000000001, 15.841188, 15.823053, 15.756229000000001, 15.754235000000001, 15.880667, 15.906676999999998, 15.909417000000001, 15.803304, 15.811539000000002, 15.830957000000001, 15.8725, 15.816667, 15.863167, 15.8965, 15.883667, 15.810784, 15.848632, 15.83818, 15.8515, 15.880167000000002, 15.88, 15.899000000000001, 15.823909, 15.726833, 15.727667000000002, 15.722853, 15.841662, 15.818754, 15.870332999999999, 15.845664000000001, 15.854111999999999, 15.846882, 15.839644, 15.853667000000002, 15.829715, 15.8645, 15.832703, 15.812671, 15.860345, 15.748833, 15.838676000000001, 15.80853, 15.815167, 15.813253, 15.8925, 15.806784, 15.845667, 15.880019, 15.8307, 15.842918, 15.846832999999998, 15.822222, 15.825981, 15.862074, 15.871049, 15.766952999999999, 15.778592999999999, 15.819754000000001, 15.774833, 15.867061999999999, 15.845904, 15.84268, 15.786882, 15.814748999999999, 15.866057999999999, 15.862344, 15.854869, 15.83, 15.864310999999999, 15.842913000000
675, 15.837435999999999, 15.844164000000001, 15.853667000000002, 15.844904999999999, 15.840917000000001, 15.866333, 15.833692999999998, 15.837926000000001, 15.889000000000001, 15.8385, 15.8755, 15.833943, 15.851667, 15.829667, 15.812022, 15.822982999999999, 15.826970999999999, 15.852667000000002, 15.818, 15.831332999999999, 15.848832999999999, 15.8565, 15.828716, 15.836433999999999, 15.830457999999998, 15.830457999999998, 15.840925, 15.811518, 15.861832999999999, 15.839917000000002, 15.815952, 15.829, 15.868, 15.818248, 15.813015, 15.759975, 15.838178, 15.828968, 15.778410000000001, 15.823978, 15.788873, 15.815510999999999, 15.817503, 15.804806, 15.874298000000001, 15.832953, 15.829713, 15.847999999999999, 15.850333, 15.8315, 15.878278, 15.886992000000001, 15.853667000000002, 15.844903, 15.853876000000001, 15.845653, 15.840419, 15.809833, 15.847999999999999, 15.832194, 15.853376999999998, 15.853667000000002, 15.851167000000002, 15.8475, 15.83816700000000 ...

# %% [markdown]
# ## Exploiting differents results obtained previously

# %%
def preprocessing_cluster(data):
    data=data.loc[data['labels']!='-1'] #removing alll noise points
    return data

def visualize_all(data):
    temp = data.loc[data.groupby('labels')['mag'].idxmax()]
    return temp.index.tolist()

# %% [markdown]
# ## Time Clustering

# %%
def select_cluster(label,data):
    cluster_df=data.loc[(data['labels']==label)]
    cluster_df.sort_values(by=['sec'])
    return cluster_df



def get_mainshock(data):
    id_mainshock=data['mag'].idxmax()
    date1=data.loc[id_mainshock][5]
    main_df=data.drop(index=id_mainshock)
    print(id_mainshock)
    return main_df,date1


    
def nearest(items, pivot):
    return min(items, key=lambda x: abs(x - pivot))


def get_sismic_seq(cluster,date1):
    closest_date= nearest(cluster['date'],date1)
    list_index=[]
    while (date1 -timedelta(days=2) < closest_date < date1+timedelta(days=2) ):
        new_indexes=cluster.loc[cluster['date']==closest_date].index.values
        list_index.extend(new_indexes)
        cluster=cluster.drop(index=new_indexes)
        date1=closest_date

        closest_date=nearest(cluster['date'],date1)
    return cluster,list_index

df1=preprocessing_cluster(df1)

# %% [markdown]
# ## Loi OmoriUtsu

# %% [markdown]
# ### Every clusters from DBSCAN low dist_min

# %% [markdown]
# ##### Label 0

# %%
time = np.array(df.loc[df['labels']=="0"]['sec'])
Ms_pourcent = GraphInterEventTime(time)
print(Ms_pourcent)
# Out:
# 4.196573267720559

# %% [markdown]
# ##### Label 1

# %%
time = np.array(df.loc[df['labels']=="1"]['sec'])
Ms_pourcent = GraphInterEventTime(time)
print(Ms_pourcent)
# Out:
# 11.109862682759955

# %% [markdown]
# ###### Label 2

# %%
time =np.array(df.loc[df['labels']=="2"]['sec'])
Ms_pourcent = GraphInterEventTime(time)
print(Ms_pourcent)
# Out:
# 18.213061937383173

# %% [markdown]
# On remarque que pour les **Saintes**, un clustering spatial semble dejà dégager des séquences sysmiques suivant **la Loi OmoriUtsu**.
# Ce qui parait assez logique, car les données ne couvrent qu'un faible intervalle temporelle, on ne retrouve donc pas de chevauchement entre séquence
# sysmique.
#
#
#
# Ensuite au sein même de ces séquences sysmiques ont va essayer d'en extraire des sous-séquences sysmiques qui suivent aussi la loi d'OmoriUtsu

# %%
df3=df.copy()  
cluster_df=select_cluster("0",df3)
cluster_df,date1=get_mainshock(cluster_df)
clust,indexes=get_sismic_seq(cluster_df,date1)

time =np.array(df.loc[indexes]['sec'])
Ms_pourcent = GraphInterEventTime(time)
print(Ms_pourcent)
# Out:
# 2227
# 54.68875668108045

# %% [markdown]
# ## Only time clustering

# %%
df4=loading_data(raw_data)
df4,date1=get_mainshock(df4)
clust,indexes=get_sismic_seq(df4,date1)

time =np.array(df4.loc[indexes]['sec'])
Ms_pourcent = GraphInterEventTime(time)
print(Ms_pourcent)
# Out:
# 2227
# 50.22530209726618

# %%
def GraphInterEventTime(time):

    time.sort()
    Norm_IET = np.diff(time) * np.size(time) / (time.max() - time.min())

    beta = Norm_IET.var() / Norm_IET.mean()
    delta = 4.4 * (1 - 4 * (Norm_IET.mean() / beta - 0.5) ** 2)
    Ms_pourcent = Norm_IET.mean() / beta * 100 + delta

    Tmp = Norm_IET[Norm_IET> 0]
    sample_Norm_IE = np.linspace(Tmp.min(), Tmp.max(), 100)
    density_Norm_IET = stats.gaussian_kde(Norm_IET)

    gamma = Norm_IET.mean() / beta
    C = 1 / (math.gamma(gamma) * beta ** gamma)
    proba = C * sample_Norm_IE ** (gamma - 1) * np.exp(-sample_Norm_IE / beta)

    x_log = np.logspace(np.log10(Tmp.min()), np.log10(Tmp.max()), 100)

    fig, ax = plt.subplots()
    ax.plot(sample_Norm_IE, proba, label='Data')
    ax.plot(x_log, 1 / (2 * x_log), label='OU')
    ax.plot(x_log, np.exp(-1 * x_log) / 2, label='Poisson')
    ax.set_xscale('log')
    ax.set_xlabel('Normalized IET')
    ax.set_yscale('log')
    ax.set_ylabel('Probability')
    ax.legend()
    plt.show()


    if Ms_pourcent <= 100:
        return Ms_pourcent
    elif (1 / beta) * 100 <= 100:
        return 1 / beta

# %%
from pyproj import Proj, transform
import pyproj
inProj = Proj('epsg:2154')
outProj = Proj('epsg:4326')
dff=pd.read_csv("./data_SNat/ReNaSS_Essaim_Barcelonnette_2003-2015.txt",delimiter='\t')

dff['p0'],dff['p1']=transform(inProj,outProj,dff['p0'].values,dff['p1'].values)

dff.to_csv("barcelonnette_2003-2015.csv")
# Out:
# <ipython-input-86-395eb57bb46f>:7: DeprecationWarning:
#
# This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1

# %%
bar_df= pd.read_csv("barcelonnette_2003-2015.csv",index_col=0)
bar_df=transform_todatetime(bar_df)
bar_df['date']=bar_df['sec'].dt.date

# %%
df_test=bar_df.copy()
df_test['date']=df_test['sec'].dt.date
clusters = DBSCAN(eps = 0.02, min_samples=20)
df_test.rename(columns={'p0': 'lat', 'p1': 'lon'}, inplace=True)
clusters.fit(df_test[['lat', 'lon']])
df_test['labels'] = [str(e) for e in clusters.labels_]
import plotly.express as px



fig = px.scatter_mapbox(df_test, lat="lat", lon="lon", color='labels')

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="a383d255-d022-42ef-8cda-0ecc852ccc88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a383d255-d022-42ef-8cda-0ecc852ccc88")) {                    Plotly.newPlot(                        "a383d255-d022-42ef-8cda-0ecc852ccc88",                        [{"hovertemplate": "labels=0<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "lat":